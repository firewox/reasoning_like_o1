# %% [markdown]
# # 2. 使用在线 LM 解决 模拟o1 step by step思考

# %% [markdown]
# ### ①qwen-plus问题
# - model: qwen-plus（2024-12-20）
# - remote：https://dashscope.aliyuncs.com/compatible-mode/v1
# - temperature: 0.2
# - prompt: strawberry单词中一共出现了多少个r
# - messages: '''
# [
#         {"role": "system", "content": """您是一个专业的人工智能助手，能够逐步解释您的推理过程。在每个步骤中，提供一个标题来描述您在该步骤中所做的事情，并附上相关内容。决定是否需要另一个步骤，或者是否准备好给出最终答案。以 JSON 格式回应，包含 'title'、'content' 和 'next_action'（可选值为 'continue' 或 'final_answer'）的键。尽可能使用多的推理步骤，至少要有 3 个。要意识到作为语言模型的局限性，以及您能做和不能做的事情。在您的推理中，探讨替代答案。考虑到您可能是错误的，如果您的推理中有错误，指出错误的地方。全面测试所有其他可能性。您可能会错。当您说要重新审视时，实际上要进行重新审视，并使用另一种方法做到这一点。不要仅仅说您在重新审视。使用至少 3 种方法来推导答案。遵循最佳实践。
#
# 有效 JSON 响应的示例：
# ```json
# {
#     "title": "Identifying Key Information",
#     "content": "To begin solving this problem, we need to carefully examine the given information and identify the crucial elements that will guide our solution process. This involves...",
#     "next_action": "continue"
# }```
# """},
#         {"role": "user", "content": prompt},
#         {"role": "assistant", "content": "谢谢你！我现在将按照我的指示，逐步思考，从头开始分解问题。"}
#     ]
# '''
# - 出现问题：模型出现幻觉，一直重复 “首先，我们需要识别问题的关键信息。问题是要求我们找出单词'strawberry'中'r'字母出现的次数。为了回答这个问题，我们需要仔细查看这个单词并计算'r'的出现次数。”

# %%
from IPython.display import Image
Image("./img/qwen-plusAI-2024-12-20.JPG")

# %% [markdown]
# ### ②海螺AI MinMaxAI问题
# - model: MinMaxAI（2024-12-20）
# - prompt: 明朝蓟州兵变
# - messages: '''
# https://hailuoai.com/share/chat/BzqqqA26?xx=JgP6pRlmGgZ3
# '''
# - 出现问题：模型出现幻觉，一直重复 “军备废弛”

# %%
Image("./img/hailuoAI-2024-12-20.jpg")
